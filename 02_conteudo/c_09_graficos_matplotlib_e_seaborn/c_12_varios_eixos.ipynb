# %% [markdown]
# # Trabalhando com eixos

# %% [markdown]
# ## Mais de um eixo y em uma figura
#
# Crie uma figura de um gráfico de precipitação com um eixo secundário para a temperatura, para mostrar a relação entre a temperatura e a precipitação em uma cidade.

# %%
meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
precipitacao_media = [200, 180, 160, 100, 60, 30, 30, 35, 60, 100, 160, 200]
temperatura_media = [30, 29, 27, 25, 23, 22, 22, 23, 24, 25, 26, 28]

# %%
import matplotlib.pyplot as plt

# Define o primeiro eixo
fig, ax1 = plt.subplots()

# Paletas de cores do tableau - um dos sistemas de cor da matplotlib
cor_temperatura = 'tab:red'
cor_precipitacao = 'tab:blue'

ax1.bar(meses, precipitacao_media, color=cor_precipitacao, label='Precipitação média (mm)')
ax1.set_ylabel('Precipitação média (mm)', color=cor_precipitacao)
ax1.tick_params(axis='y', labelcolor=cor_precipitacao)
ax1.set_ylim(0, 250)

# Define o segundo eixo, mantendo o mesmo eixo x
ax2 = ax1.twinx()
ax2.plot(meses, temperatura_media, linewidth=2, color=cor_temperatura, label='Temperatura média (°C)')
ax2.set_xlabel('Mês')
ax2.set_ylabel('Temperatura média (°C)', color=cor_temperatura)
ax2.tick_params(axis='y', labelcolor=cor_temperatura)
# Limite inferior e superior de y
ax2.set_ylim(20, 35)

"""
para colocar a legenda somente do eixo 1:
ax1.legend()
para colocar a legenda somente do eixo 2:
ax2.legend()
"""

# Adiciona legenda única para os dois eixos
# Bbox = bounding box
# bbox_to_anchor define a distância da caixa da legenda - em % da figura geral
# Ao utilizar o bbox_transform = ax1.transAxes, a referência para posição da legenda passa a ser o eixo ax1 

fig.legend(bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes)

plt.title('Temperatura e Precipitação ao Longo do Ano')

plt.show()
