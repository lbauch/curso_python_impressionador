# %% [markdown]
# ## Exercício para os três tipos básicos de gráficos
#
# Você recebeu, na forma de listas, os dados de receita anual de uma empresa de tecnologia, em bilhões de dólares, nos últimos anos. Com esses dados, você deve criar três gráficos, um de cada tipo abaixo listado, para visualizar esses dados. Os gráficos devem conter título e rótulos dos eixos. O nome da empresa é "Apple Inc.".
#
# Tipos de gráficos:
#
# - Gráfico de linhas
#   - além da linha, mostre os pontos de cada valor
# - Gráfico de barras
#   - adicione o valor de cada barra no gráfico
# - Gráfico de dispersão
#   - ligue a grade do gráfico
#
# Cada gráfico deve usar uma paleta de cores diferente.
#
# Os dados são:
#
# Ano | Receita (em bilhões de dólares)
# --- | ---
# | 2009 | 42,9
# | 2010 | 65,2
# | 2011 | 108,2
# | 2012 | 156,5
# | 2013 | 170,9
# | 2014 | 182,8
# | 2015 | 233,7
# | 2016 | 215,6
# | 2017 | 229,2
# | 2018 | 265,6
# | 2019 | 260,2
# | 2020 | 274,5
# | 2021 | 365,8
# | 2022 | 394,3
#
# Qual o tipo de gráfico mais adequado para visualizar esses dados?

# %%
# convertendo os dados para listas
ano = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
receita = [42.9, 65.2, 108.2, 156.5, 170.9, 182.8, 233.7, 215.6, 229.2, 265.6, 260.2, 274.5, 365.8, 394.3]
receita1 = [50, 78.2, 95, 110, 116.7, 200.8, 257.7, 199.6, 253.2, 290.6, 283.2, 227.5, 305.8, 409.9]

# %%
# gráfico de linhas
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

plt.plot(ano, receita, marker='o')
plt.plot(ano, receita1, marker='x')
plt.title('Receita da Apple Inc. (em bilhões de dólares)')
plt.xlabel('Ano')
plt.ylabel('Receita (em bilhões de dólares)')
plt.show()

# %% [markdown]
# Diferentes tipos de marcadores: https://matplotlib.org/stable/gallery/lines_bars_and_markers/marker_reference.html

# %%
# gráfico de barras
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Set3').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

plt.bar(ano, receita)
plt.title('Receita da Apple Inc. (em bilhões de dólares)')
plt.xlabel('Ano')
plt.ylabel('Receita (em bilhões de dólares)')
plt.show()

# %%
# gráfico de barras aprimorado
import matplotlib.pyplot as plt
from cycler import cycler

plt.figure(figsize=(10, 6))

cores = plt.get_cmap('Set3').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

# barras = plt.bar(ano, receita, color=cores)  # muito colorido, evitar
barras = plt.bar(ano, receita)
plt.bar_label(barras, fontsize=9, fontweight='bold')

plt.xticks(ano, rotation=60)

plt.title('Receita da Apple Inc. (em bilhões de dólares)')
plt.xlabel('Ano')
plt.ylabel('Receita (em bilhões de dólares)')
plt.show()

# %%
# gráfico de dispersão
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

plt.scatter(ano, receita)
plt.title('Receita da Apple Inc. (em bilhões de dólares)')
plt.xlabel('Ano')
plt.ylabel('Receita (em bilhões de dólares)')
plt.grid(True, linestyle=':')

plt.show()

# %%
# gráfico de dispersão
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

# adicionando tamanho e cor aos pontos
# este exemplo é apenas para mostrar a funcionalidade
# no caso em questão, talvez não seja a melhor forma de visualizar os dados
plt.scatter(ano, receita, c=receita, cmap='Reds', s=receita)
plt.title('Receita da Apple Inc. (em bilhões de dólares)')
plt.xlabel('Ano')
plt.ylabel('Receita (em bilhões de dólares)')
plt.grid(True, linestyle=':')

# cria uma barra de cores
# novamente, é apenas para mostrar a funcionalidade
# a barra mostra a relação com a cor, mas pode confundir o leitor já que há o eixo y do outro lado
# no caso em questão, talvez não seja a melhor forma de visualizar os dados
plt.colorbar()

plt.show()
